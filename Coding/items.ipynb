# %%
# Se importan las librerías que se utilizarán en este archivo.
import pandas as pd
import json
import ast

# %%
data3 = []
with open('australian_users_items.json', "r", encoding="utf-8") as f3:
    for line in f3.readlines():
        data3.append(ast.literal_eval(line))
df_items = pd.DataFrame(data3)
df_items.head(5)
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %%
# Se eliminan las columnas irrelevantes
df_items = df_items.drop(['steam_id', 'user_url'], axis=1)

# %%
df_items.head(10)
# Out:
#                     user_id  items_count  \
# 0         76561197970982479          277
# 1                   js41637          888
# 2                 evcentric          137
# 3                Riot-Punch          328
# 4                     doctr          541
# 5  MinxIsBetterThanPotatoes          371
# 6                NitemarePK          304
# 7                themanwich          258
# 8                 maplemage          629
# 9                    Wackky            0
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...
# 5  [{'item_id': '50', 'item_name': 'Half-Life: Op...
# 6  [{'item_id': '240', 'item_name': 'Counter-Stri...
# 7  [{'item_id': '220', 'item_name': 'Half-Life 2'...
# 8  [{'item_id': '240', 'item_name': 'Counter-Stri...
# 9                                                 []

# %%
# Se desanida la columna items para ver su información.
df_items['playtime_forever'] = df_items['items'].apply(lambda x: x[0].get('playtime_forever') if len(x) > 0 else 0)
df_items['playtime_2weeks'] = df_items['items'].apply(lambda x: x[0].get('playtime_2weeks') if len(x) > 0 else 0)
df_items['id'] = df_items['items'].apply(lambda x: x[0].get('item_id') if len(x) > 0 else 0)
df_items['playtime_forever'] = df_items['playtime_forever'].astype(int)
df_items['playtime_2weeks'] = df_items['playtime_2weeks'].astype(int)

# %%
df_items.head(10)
# Out:
#                     user_id  items_count  \
# 0         76561197970982479          277
# 1                   js41637          888
# 2                 evcentric          137
# 3                Riot-Punch          328
# 4                     doctr          541
# 5  MinxIsBetterThanPotatoes          371
# 6                NitemarePK          304
# 7                themanwich          258
# 8                 maplemage          629
# 9                    Wackky            0
#
#                                                items  playtime_forever  \
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...                 6
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...                 0
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...               923
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...                 0
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...              1131
# 5  [{'item_id': '50', 'item_name': 'Half-Life: Op...               256
# 6  [{'item_id': '240', 'item_name': 'Counter-Stri...              3529
# 7  [{'item_id': '220', 'item_name': 'Half-Life 2'...               219
# 8  [{'item_id': '240', 'item_name': 'Counter-Stri...              5751
# 9                                                 []                 0
#
#    playtime_2weeks    id
# 0                0    10
# 1                0    10
# 2                0  1200
# 3                0    10
# 4                0   300
# 5                0    50
# 6                0   240
# 7                0   220
# 8                0   240
# 9                0     0

# %%
# Se exporta el dataset limpio
df_items.to_csv('df_items.csv', index=False)
