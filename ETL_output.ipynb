# %%
# Se importan las librerías que se utilizarán en este archivo.
import pandas as pd
import json

# %%
# Se crea una lista para posteriormente cargar allí los datos provenientes del arhcivo json, el procedimiento se realiza abriendo el archivo json  e iterando cada linea dentro del archivo para guardar linea a linea en la lista creada.
data1 = []
with open('output_steam_games.json') as f1:
    for line in f1:
        data1.append(json.loads(line))

# %%
#creo un Data Frame a partir de la lista creada en el paso anterior.
df_output = pd.DataFrame(data1)

# %%
#realizo un poco de EDA sobre el archivo con el fin de conocer a qué tipo de informaicón me estoy enfrentando y poder identificar columnas clave.
conteo_NaN = df_output.isna().sum().sum()
print("El número de valores NaN es:", conteo_NaN)
df_output.head(5)
# Out:
# El número de valores NaN es: 1168997
#   publisher genres app_name title  url release_date tags reviews_url specs  \
# 0       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 1       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 2       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 3       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
# 4       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN   NaN
#
#   price early_access   id developer
# 0   NaN          NaN  NaN       NaN
# 1   NaN          NaN  NaN       NaN
# 2   NaN          NaN  NaN       NaN
# 3   NaN          NaN  NaN       NaN
# 4   NaN          NaN  NaN       NaN

# %%
df_output.tail(5)
# Out:
#               publisher                                 genres  \
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
# 120444               Maze Run VR                       NaN
#
#                                                       url release_date  \
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# ...

# %%
# Se limpia el Data Frame de NaN y se eliminan columnas que considero irrelevantes.
df_output = df_output.dropna()
df_output = df_output.drop(['publisher', 'reviews_url','url','tags', 'app_name', 'specs', 'price', 'early_access', 'developer'], axis=1)

# %%
genres = df_output['genres']

# %%
genres
# Out:
# 88310         [Action, Casual, Indie, Simulation, Strategy]
# 88311                  [Free to Play, Indie, RPG, Strategy]
# 88312     [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                           [Action, Adventure, Casual]
# 88315                       [Action, Adventure, Simulation]
#                                 ...
# 120439                   [Action, Adventure, Casual, Indie]
# 120440                [Casual, Indie, Simulation, Strategy]
# 120441                            [Casual, Indie, Strategy]
# 120442                          [Indie, Racing, Simulation]
# 120443                                      [Casual, Indie]
# Name: genres, Length: 22530, dtype: object

# %%
df_exploded = genres.explode('genres')

# %%
print ("Número total de géneros distintos:", len(df_exploded.unique()))
df_exploded.unique()
# Out:
# Número total de géneros distintos: 21
# array(['Action', 'Casual', 'Indie', 'Simulation', 'Strategy',
#        'Free to Play', 'RPG', 'Sports', 'Adventure', 'Racing',
#        'Early Access', 'Massively Multiplayer',
#        'Animation &amp; Modeling', 'Web Publishing', 'Education',
#        'Software Training', 'Utilities', 'Design &amp; Illustration',
#        'Audio Production', 'Video Production', 'Photo Editing'],
#       dtype=object)

# %%
df_output.head(5)
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
#
#                          title release_date      id
# 88310      Lost Summoner Kitty   2018-01-04  761140
# 88311                Ironbound   2018-01-04  643980
# 88312  Real Pool 3D - Poolians   2017-07-24  670290
# 88313                  弹炸人2222   2017-12-07  767400
# 88315    Battle Royale Trainer   2018-01-04  772540

# %%
# Creamos dummies para columna "genres"
df_output['genres'] = df_output['genres'].fillna('[]')  # Rellenar los valores faltantes con una lista vacía
df_output['genres'] = df_output['genres'].apply(lambda x: ', '.join(x))  # Convertir la lista de géneros a una cadena separada por comas

# Se crean variables ficticias para cada género
dummy_genres = df_output['genres'].str.get_dummies(', ')

# Se Concatenan las variables ficticias con el DataFrame original
df_dummies = pd.concat([df_output, dummy_genres], axis=1)

# %%
df_dummies.head(5)
# Out:
#                                                 genres  \
# 88310      Action, Casual, Indie, Simulation, Strategy
# 88311               Free to Play, Indie, RPG, Strategy
# 88312  Casual, Free to Play, Indie, Simulation, Sports
# 88313                        Action, Adventure, Casual
# 88315                    Action, Adventure, Simulation
#
#                          title release_date      id  Action  Adventure  \
# 88310      Lost Summoner Kitty   2018-01-04  761140       1          0
# 88311                Ironbound   2018-01-04  643980       0          0
# 88312  Real Pool 3D - Poolians   2017-07-24  670290       0          0
# 88313                  弹炸人2222   2017-12-07  767400       1          1
# 88315    Battle Royale Trainer   2018-01-04  772540       1          1
#
#        Animation &amp; Modeling  Audio Production  Casual  \
# 88310                         0                 0       1
# 88311                         0                 0       0
# ...

# %%
# Se reemplaza un detalle en los títulos
df_dummies.columns = df_dummies.columns.str.replace("&amp;", "&")

# %%
df_dummies.head(2)
# Out:
#                                             genres                title  \
# 88310  Action, Casual, Indie, Simulation, Strategy  Lost Summoner Kitty
# 88311           Free to Play, Indie, RPG, Strategy            Ironbound
#
#       release_date      id  Action  Adventure  Animation & Modeling  \
# 88310   2018-01-04  761140       1          0                     0
# 88311   2018-01-04  643980       0          0                     0
#
#        Audio Production  Casual  Design & Illustration  ...  Photo Editing  \
# 88310                 0       1                      0  ...              0
# 88311                 0       0                      0  ...              0
#
#        RPG  Racing  Simulation  Software Training  Sports  Strategy  \
# 88310    0       0           1                  0       0         1
# 88311    1       0           0                  0       0         1
#
#        Utilities  Video Production  Web Publishing
# 88310          0                 0               0
# ...

# %%
#Se exporta el dataset en CSV.
#df_dummies.to_csv('df_dummies.csv', index=False)

# %%
df_titulos = df_dummies[['title', 'id']]

# %%
df_titulos = df_titulos.rename(columns={"id": "item_id"})

# %%
df_titulos
# Out:
#                            title item_id
# 88310        Lost Summoner Kitty  761140
# 88311                  Ironbound  643980
# 88312    Real Pool 3D - Poolians  670290
# 88313                    弹炸人2222  767400
# 88315      Battle Royale Trainer  772540
# ...                          ...     ...
# 120439              Kebab it Up!  745400
# 120440            Colony On Mars  773640
# 120441  LOGistICAL: South Africa  733530
# 120442             Russian Roads  610660
# 120443       EXIT 2 - Directions  658870
#
# [22530 rows x 2 columns]

# %%
df_sample = pd.read_csv("df_sample.csv")
titulosXXX = df_sample.merge(df_titulos, on="item_id")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\cesar\OneDrive\Desktop\PI MLOps - STEAM-20230925T183436Z-001\PI MLOps - STEAM\ETL_output.ipynb Celda 20 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/cesar/OneDrive/Desktop/PI%20MLOps%20-%20STEAM-20230925T183436Z-001/PI%20MLOps%20-%20STEAM/ETL_output.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> df_sample = pd.read_csv("df_sample.csv")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cesar/OneDrive/Desktop/PI%20MLOps%20-%20STEAM-20230925T183436Z-001/PI%20MLOps%20-%20STEAM/ETL_output.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> titulosXXX = df_sample.merge(df_titulos, on="item_id")
#
# ...

# %%
unique_titles = df_titulos.drop_duplicates(subset=['title'])
unique_titles
# Out:
#                            title item_id
# 88310        Lost Summoner Kitty  761140
# 88311                  Ironbound  643980
# 88312    Real Pool 3D - Poolians  670290
# 88313                    弹炸人2222  767400
# 88315      Battle Royale Trainer  772540
# ...                          ...     ...
# 120439              Kebab it Up!  745400
# 120440            Colony On Mars  773640
# 120441  LOGistICAL: South Africa  733530
# 120442             Russian Roads  610660
# 120443       EXIT 2 - Directions  658870
#
# [22513 rows x 2 columns]

# %%
search_value = 1
result = unique_titles.loc[unique_titles['item_id'] == search_value, 'title']
result
# Out:
# Series([], Name: title, dtype: object)

# %%
unique_titles.to_csv('unique_titles.csv', index=False)
